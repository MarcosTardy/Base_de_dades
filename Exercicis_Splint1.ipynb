# %% [markdown]
# # Exercicis splint 1 MySQL

# %% [markdown]
# ## Exercici 1

# %% [markdown]
# ![Exercici_1_SQL.png](attachment:Exercici_1_SQL.png)

# %%
#A la imatge d'adalt es mostra la base de dades "movies" de forma esquemática. Els rectangles representen taules. A la part superior hi ha el seu títol i dins hi han els seus atributs. Les fletxes representen les relacions entre les taules.
#El proposit d'aquesta BD es emmagatzemar dades sobre les pelicules, així com el seu genere, les persones que hi participen, els seus rols, etc.
#Com que hem de gestionar una gran quantitat de dades, aquestes es divideixen en taules interrelacionades entre si. Cada taula conté molta informació. Per exemple la taula tb_movie conté, per a cada película registrada com pot ser Braveheart o Ocho Apellidos Vascos (files), els seus atributs (columnes). Els atributs d'aquestes películes serien el id, el títul, la data,el format i el génere. Ja que un génere com pot ser comedia el poden tenir una o més películes, es crea una taula tb_genres amb tots els géneres y aquesta taula es relaciona amb el atribut genres_id de la taula tb_movies.

#TAULA tb_movie: Guarda el id de totes les películes com a primary key, aixó significa que els ids de le películes son exclusius i han de tenir algun valor. La seva clau foranea es movie_genre_id que relaciona aquesta taula amb genre_id de la taula tb_genre. La cardinalitat es 1-N, ja que una película només pot tenir un genere, però un genere el poden tenir moltes películes.
#Al mateix temps, aquesta taula relaciona la seva clau primaria amb movie_id de la taula tb_movie_person. 

#TAULA tb_genre: La seva clau primaria está relacionada amb movie_genre_id de la taula tb_movie. D'aquesta manera es pot consultar el génere de cada película.

#TAULA tb_role: Aquesta taula emmagatzema els tipus de rol que hi pot haver en una película. Té una clau primaria, role_id, que es relaciona amb el atribut role_id de la llista tb_movie_person. 

#TAULA tb_person: Aquesta taula te la singularitat de que es relaciona amb ella mateixa, això es diu interrelació recursiva. Es relaciona el person_id (clau primária) amb person_parent_id (foreign key). Una persona pot no tenir familiar per tant el atribut person_parent_id pot ser null. La cardinalitat es 1-N.
#També relaciona la seva clau primària amb person_id de la taula tb_movie_person

#TAULA tb_movie_person:Si volem relacionar una persona que participa a una película amb el seu rol y amb la película en la que ha participat. Llavors es crea una taula tb_movie_person per relacionar la taula tb_movie , tb_role y tb_person. Aquesta taula es feble ja que depén de les tres taules que relaciona, ja que per si sola no te reó de ser.

# %% [markdown]
# ## Exercici 2

# %% [markdown]
# ![Exercici2_SQL.png](attachment:Exercici2_SQL.png)

# %% [markdown]
# ## Exercici 3

# %% [markdown]
# ![Exeercici3_SQL.png](attachment:Exeercici3_SQL.png)

# %% [markdown]
# ## Exercici 4

# %% [markdown]
# ## Exercici 5

# %% [markdown]
# ![Captura%20de%20pantalla%20%284%29.png](attachment:Captura%20de%20pantalla%20%284%29.png)

# %% [markdown]
# ## Exercici 6

# %% [markdown]
# ![Captura%20de%20pantalla%20%285%29.png](attachment:Captura%20de%20pantalla%20%285%29.png)

# %% [markdown]
# ## Exercici 7

# %% [markdown]
# ![Captura%20de%20pantalla%20%286%29.png](attachment:Captura%20de%20pantalla%20%286%29.png)

# %% [markdown]
# ### per fer aquest exercici primer he hagut de deshabilitar el mode segur de mysql.
